# %% [markdown]
# # Exercises
# - The goal of the exercises
# - Get comfortable with NumPy
# - Establish workflows with NumPy

# %% [markdown]
# ## Questions?
# - If you have any questions:
#     - Please see the answers given in a video lecture in the course
#     - There the full solutions are given

# %% [markdown]
# ## Structure
# - The exercises are divided into 7 steps.
# - The exercises should be solved in the order 1 to 7.
# - If you cannot solve a step, please follow the answers in the video lecture.
# - Then proceed to next step and see if you can solve that.

# %% [markdown]
# ### Step 1
# - Import numpy as np
# - Import pandas as pd
# - Import matplotlib.pyplot as plt
#     - Remember: %matplotlib notebook

# %% [markdown]
# ### Step 2
# - Create a ndarray of length 5 with zeros

# %%
# Out:
# array([0., 0., 0., 0., 0.])

# %% [markdown]
# ### Step 3
# - Create a ndarray with random numbers from 0 to 1 (not incluted) of length 5
# - Assign it to a variable
# - The output below is just an example, you will get different values

# %%
# Out:
# array([0.31146024, 0.08785368, 0.13200128, 0.18985114, 0.42689947])

# %% [markdown]
# ### Step 4
# - Now we will normalize the ndarray from last step.
#     - Normalize means that the entries sum up to 1
# - This can be done by dividing it by the sum of the entries
# - Do that and assign it to a variable
# - The output is just an example, you should get different values

# %%
# Out:
# array([0.27129128, 0.07652321, 0.1149771 , 0.16536608, 0.37184234])

# %% [markdown]
# ### Step 5
# - Create a Series of length 5 with all entries 100
# - Multiply the series with the ndarray from last step
# - The output below is just an example, you should get different values

# %%
# Out:
# array([0.27129128, 0.07652321, 0.1149771 , 0.16536608, 0.37184234])

# %% [markdown]
# ### Step 6
# - Plot the function $y = x^2 + 1$, for range -500 to 500
# - Substeps
#     - Create ndarray **x** with range 1001 and subtract 500
#     - Create ndarray **y** and assign it to $x**2 + 1$.
#     - Create a figure and axis
#     - Use plot on axis with **x** and **y**

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Step 7
# - Create a random plot
# - Create 5000 random values and assign it to **x**
# - Create 5000 random values and assign it to **y**
# - Assign **c = x*y**
# - Make a scatter plot with x, y, alpha=0.3, c=c.

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
