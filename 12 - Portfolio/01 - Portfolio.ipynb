# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
tickers = ["FB", "NVDA", "AMZN", "HP", "AAPL"]

df_list = []
for ticker in tickers:
    df = pd.read_csv("ticker-" + ticker.lower() + ".csv", index_col=0, parse_dates=True)
    df_list.append(df['Adj Close'])

data = pd.concat(df_list, axis=1)
data.columns = tickers

# %%
data.head()
# Out:
#                     FB        NVDA         AMZN         HP       AAPL
# Date
# 2018-01-02  181.419998  197.695740  1189.010010  54.010021  41.442081
# 2018-01-03  184.669998  210.706848  1204.199951  54.257961  41.434864
# 2018-01-04  184.330002  211.817535  1209.589966  54.877815  41.627323
# 2018-01-05  186.850006  213.612518  1229.140015  55.125751  42.101261
# 2018-01-08  188.279999  220.157761  1246.869995  56.671265  41.944889

# %%
data = data/data.iloc[0]

# %%
data.head()
# Out:
#                   FB      NVDA      AMZN        HP      AAPL
# Date
# 2018-01-02  1.000000  1.000000  1.000000  1.000000  1.000000
# 2018-01-03  1.017914  1.065814  1.012775  1.004591  0.999826
# 2018-01-04  1.016040  1.071432  1.017308  1.016067  1.004470
# 2018-01-05  1.029931  1.080511  1.033751  1.020658  1.015906
# 2018-01-08  1.037813  1.113619  1.048662  1.049273  1.012133

# %%
data.tail()
# Out:
#                   FB      NVDA      AMZN        HP      AAPL
# Date
# 2020-12-24  1.473928  2.629040  2.668346  0.448065  3.184444
# 2020-12-28  1.526844  2.610071  2.761928  0.438437  3.298338
# 2020-12-29  1.525631  2.618822  2.793921  0.434919  3.254421
# 2020-12-30  1.498567  2.659794  2.763518  0.436586  3.226672
# 2020-12-31  1.505677  2.641433  2.739195  0.428809  3.201818

# %%
portfolio = np.array([.2, .15, .25, .20, .20])

# %%
np.sum(portfolio)
# Out:
# 1.0

# %%
(data*portfolio*100000).tail()
# Out:
#                       FB          NVDA          AMZN           HP  \
# Date
# 2020-12-24  29478.557667  39435.599422  66708.646591  8961.300226
# 2020-12-28  30536.876066  39151.071287  69048.198374  8768.743198
# 2020-12-29  30512.622817  39282.332118  69848.024254  8698.385687
# 2020-12-30  29971.336993  39896.915667  69087.940191  8731.712892
# 2020-12-31  30113.549379  39621.492062  68479.867808  8576.186170
#
#                     AAPL
# Date
# 2020-12-24  63688.886561
# 2020-12-28  65966.765015
# 2020-12-29  65088.427219
# 2020-12-30  64533.438735
# 2020-12-31  64036.360045

# %%
(np.sum(data*portfolio*100000, axis=1)).tail()
# Out:
# Date
# 2020-12-24    208272.990467
# 2020-12-28    213471.653941
# 2020-12-29    213429.792094
# 2020-12-30    212221.344478
# 2020-12-31    210827.455464
# dtype: float64

# %%
(np.sum(data*portfolio*100000, axis=1)).head()
# Out:
# Date
# 2018-01-02    100000.000000
# 2018-01-03    101753.203290
# 2018-01-04    102235.737917
# 2018-01-05    103381.331172
# 2018-01-08    104905.219861
# dtype: float64

# %%
fig, ax = plt.subplots()
np.sum(data*portfolio*100000, axis=1).plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots()
(data*portfolio*100000).plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>
