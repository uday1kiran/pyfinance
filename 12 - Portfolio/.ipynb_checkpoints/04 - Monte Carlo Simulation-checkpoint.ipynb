# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
tickers = ["FB", "NVDA", "AMZN", "HP", "AAPL"]

df_list = []
for ticker in tickers:
    df = pd.read_csv("ticker-" + ticker.lower() + ".csv", index_col=0, parse_dates=True)
    df_list.append(df['Adj Close'])

data = pd.concat(df_list, axis=1)
data.columns = tickers

# %%
log_return = np.log(data/data.shift())

# %%
log_return
# Out:
#                   FB      NVDA      AMZN        HP      AAPL
# Date
# 2018-01-02       NaN       NaN       NaN       NaN       NaN
# 2018-01-03  0.017756  0.063739  0.012694  0.004580 -0.000174
# 2018-01-04 -0.001843  0.005257  0.004466  0.011359  0.004634
# 2018-01-05  0.013579  0.008438  0.016033  0.004508  0.011321
# 2018-01-08  0.007624  0.030181  0.014322  0.027650 -0.003721
# ...              ...       ...       ...       ...       ...
# 2020-12-24 -0.002652 -0.001192 -0.003957 -0.012729  0.007683
# 2020-12-28  0.035272 -0.007241  0.034470 -0.021722  0.035141
# 2020-12-29 -0.000795  0.003347  0.011517 -0.008056 -0.013404
# 2020-12-30 -0.017899  0.015524 -0.010942  0.003824 -0.008563
# 2020-12-31  0.004734 -0.006927 -0.008840 -0.017972 -0.007732
#
# [756 rows x 5 columns]

# %%
fig, ax = plt.subplots(5)
log_return.hist(bins=100, ax=ax)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
