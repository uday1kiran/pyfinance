# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
tickers = ["FB", "NVDA", "AMZN", "HP", "AAPL"]

df_list = []
for ticker in tickers:
    df = pd.read_csv("ticker-" + ticker.lower() + ".csv", index_col=0, parse_dates=True)
    df_list.append(df['Adj Close'])

data = pd.concat(df_list, axis=1)
data.columns = tickers

# %%
data = data/data.iloc[0]

# %%
data
# Out:
#                   FB      NVDA      AMZN        HP      AAPL
# Date
# 2018-01-02  1.000000  1.000000  1.000000  1.000000  1.000000
# 2018-01-03  1.017914  1.065814  1.012775  1.004591  0.999826
# 2018-01-04  1.016040  1.071432  1.017308  1.016067  1.004470
# 2018-01-05  1.029931  1.080511  1.033751  1.020658  1.015906
# 2018-01-08  1.037813  1.113619  1.048662  1.049273  1.012133
# ...              ...       ...       ...       ...       ...
# 2020-12-24  1.473928  2.629040  2.668346  0.448065  3.184444
# 2020-12-28  1.526844  2.610071  2.761928  0.438437  3.298338
# 2020-12-29  1.525631  2.618822  2.793921  0.434919  3.254421
# 2020-12-30  1.498567  2.659794  2.763518  0.436586  3.226672
# 2020-12-31  1.505677  2.641433  2.739195  0.428809  3.201818
#
# [756 rows x 5 columns]

# %%
portfolio = np.array([.2, .15, .3, .25, .1])

# %%
portfolio*10000
# Out:
# array([2000., 1500., 3000., 2500., 1000.])

# %%
data*portfolio*10000
# Out:
#                      FB         NVDA         AMZN           HP         AAPL
# Date
# 2018-01-02  2000.000000  1500.000000  3000.000000  2500.000000  1000.000000
# 2018-01-03  2035.828465  1598.720704  3038.325854  2511.476577   999.825844
# 2018-01-04  2032.080296  1607.147951  3051.925440  2540.168196  1004.469894
# 2018-01-05  2059.861184  1620.767235  3101.252314  2551.644596  1015.906047
# 2018-01-08  2075.625628  1670.428717  3145.986959  2623.182855  1012.132779
# ...                 ...          ...          ...          ...          ...
# 2020-12-24  2947.855767  3943.559942  8005.037591  1120.162528  3184.444328
# 2020-12-28  3053.687607  3915.107129  8285.783805  1096.092900  3298.338251
# 2020-12-29  3051.262282  3928.233212  8381.762910  1087.298211  3254.421361
# 2020-12-30  2997.133699  3989.691567  8290.552823  1091.464111  3226.671937
# 2020-12-31  3011.354938  3962.149206  8217.584137  1072.023271  3201.818002
#
# [756 rows x 5 columns]

# %%
np.sum(data*portfolio*10000, axis=1)
# Out:
# Date
# 2018-01-02    10000.000000
# 2018-01-03    10184.177443
# 2018-01-04    10235.791777
# 2018-01-05    10349.431375
# 2018-01-08    10527.356938
#                   ...
# 2020-12-24    19201.060156
# 2020-12-28    19649.009691
# 2020-12-29    19702.977976
# 2020-12-30    19595.514137
# 2020-12-31    19464.929555
# Length: 756, dtype: float64

# %%
fig1, ax1 = plt.subplots()
np.sum(data*portfolio*10000, axis=1).plot(ax=ax1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
(data*portfolio*10000).plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>
