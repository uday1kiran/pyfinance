# %%
import numpy as np

# %%
def roll_dice():
    return np.sum(np.random.randint(1, 7, 2))

# %%
def monte_carolo_simulation(runs=1000):
    result = np.zeros(2)
    for _ in range(runs):
        if roll_dice() == 7:
            result[0] += 1
        else:
            result[1] += 1
    return result/runs

# %%
monte_carolo_simulation()
# Out:
# array([0.174, 0.826])

# %%
d1 = np.arange(1, 7)
d2 = np.arange(1, 7)

# %%
mat = np.add.outer(d1, d2)

# %%
mat
# Out:
# array([[ 2,  3,  4,  5,  6,  7],
#        [ 3,  4,  5,  6,  7,  8],
#        [ 4,  5,  6,  7,  8,  9],
#        [ 5,  6,  7,  8,  9, 10],
#        [ 6,  7,  8,  9, 10, 11],
#        [ 7,  8,  9, 10, 11, 12]])

# %%
mat.size
# Out:
# 36

# %%
mat[mat == 7].size
# Out:
# 6

# %%
mat[mat == 7].size/mat.size
# Out:
# 0.16666666666666666

# %%
mat[mat != 7].size/mat.size
# Out:
# 0.8333333333333334

# %%
results = np.zeros(1000)

for i in range(1000):
    results[i] = monte_carolo_simulation()[0]

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fig, ax = plt.subplots()
ax.hist(results, bins=15)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([ 10.,  13.,  23.,  44., 102., 119., 113., 146., 120., 100., 106.,
#          57.,  20.,  20.,   7.]),
#  array([0.135 , 0.1392, 0.1434, 0.1476, 0.1518, 0.156 , 0.1602, 0.1644,
#         0.1686, 0.1728, 0.177 , 0.1812, 0.1854, 0.1896, 0.1938, 0.198 ]),
#  <BarContainer object of 15 artists>)
