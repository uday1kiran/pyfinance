# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
plt.plot([i for i in range(10)], color='r', linestyle='--', label='label')
plt.plot([i + 1 for i in range(10)], color='g', label='foo')
plt.legend()
plt.ylabel('Y label')
plt.xlabel('X label')
plt.title('Title')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Title')
