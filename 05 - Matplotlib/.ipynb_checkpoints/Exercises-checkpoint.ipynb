# %% [markdown]
# # Exercises
# - The goal of the exercises
#     - Get comfortable with Matplotlib
#     - Establish workflows with Matplotlib

# %% [markdown]
# ## Questions?
# - If you have any questions:
#     - Please see the answers given in a video lecture in the course
#     - There the full solutions are given

# %% [markdown]
# ## Structure
# - The exercises are divided into 7 steps.
# - The exercises should be solved in the order 1 to 7.
# - If you cannot solve a step, please follow the answers in the video lecture.
# - Then proceed to next step and see if you can solve that.

# %% [markdown]
# ### Step 1
# - Import pandas as pd
# - Then import matplotlib.pyplot as plt
# - Then set the %matplotlib notebook

# %% [markdown]
# ### Step 2
# - Read the data from CSV file stock-data.csv
# - Use the index_col=0
# - Also, it is convinient to use parse_dates=True
# - Take head of data

# %%
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  86.139999  84.342003  84.900002  86.052002   47660500.0  86.052002
# 2020-01-03  90.800003  87.384003  88.099998  88.601997   88892500.0  88.601997
# 2020-01-06  90.311996  88.000000  88.094002  90.307999   50665000.0  90.307999
# 2020-01-07  94.325996  90.671997  92.279999  93.811996   89410500.0  93.811996
# 2020-01-08  99.697998  93.646004  94.739998  98.428001  155721500.0  98.428001

# %% [markdown]
# ### Step 3
# - plot the full DataFrame from last step
# - (Note: intented to give poor experience)

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Step 4
# - make a new plot with only Close price
# - (Note: Maybe this surprices you - did a new chart come?)

# %% [markdown]
# ### Step 5
# - Make a figure and axes by calling matplotlib.pyplot from plt
# - Now make a chart with Closing price

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Step 6
# - Make new figure of 4 subplots in 2 rows and 2 columns
# - Make charts of Open, High, Low, and Close in each axes

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Step 7
# - Make a new figure
# - Make a bar chart with volume for January 2020

# %%
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>
