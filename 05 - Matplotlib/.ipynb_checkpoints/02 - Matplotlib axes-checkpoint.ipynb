# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot()

# %%
ax.plot([i for i in range(10)])

# %%
fig, axes = plt.subplots(2, 2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
axes[0][0].plot([i for i in range(10)])

# %%
import random

# %%
axes[0][1].hist([random.randrange(0, 10) for i in range(50)])
# Out:
# (array([7., 6., 3., 4., 8., 2., 4., 5., 6., 5.]),
#  array([0. , 0.9, 1.8, 2.7, 3.6, 4.5, 5.4, 6.3, 7.2, 8.1, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
axes[1][0].scatter([i for i in range(10)], [i for i in range(10)])

# %%
axes[1, 1].scatter([random.uniform(0, 1) for i in range(100)], [random.uniform(0, 1) for i in range(100)], alpha=0.3)
