# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import random

# %%
s = pd.Series([random.randrange(0, 10) for i in range(10)], index=list('abcdefghij'))

# %%
s
# Out:
# a    8
# b    5
# c    8
# d    9
# e    5
# f    3
# g    3
# h    7
# i    5
# j    3
# dtype: int64

# %%
fig1, ax1 = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s.plot.bar(ax=ax1)
# Out:
# <AxesSubplot:>

# %%
fig2, ax2 = plt.subplots(2, 1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s.plot.bar(ax=ax2[0])
# Out:
# <AxesSubplot:>

# %%
s.plot.barh(ax=ax2[1])
# Out:
# <AxesSubplot:>

# %%
d = {}
for l in 'ABC':
    d[l] = [random.uniform(0, 0.3) for i in range(6)]

# %%
df = pd.DataFrame(d, index=['ROI', 'DE', 'PE', 'Rev', 'EPS', 'FCF'])

# %%
df
# Out:
#             A         B         C
# ROI  0.272482  0.224004  0.280082
# DE   0.031691  0.154572  0.252372
# PE   0.250166  0.261677  0.058730
# Rev  0.259901  0.114941  0.038304
# EPS  0.182463  0.187069  0.169503
# FCF  0.117761  0.290650  0.109450

# %%
fig3, ax3 = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.bar(ax=ax3)
# Out:
# <AxesSubplot:>

# %%
fig4, ax4 = plt.subplots()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.barh(ax=ax4)
# Out:
# <AxesSubplot:>
