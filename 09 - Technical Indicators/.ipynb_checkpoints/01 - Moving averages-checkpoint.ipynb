# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# ### Moving Average
# - https://www.investopedia.com/terms/m/movingaverage.asp
#
# $MAn_i = \frac{C_{i-(n-1)} + C_{i-(n-2)} + \cdots + C_{i-1} + C_i}{n}$
# - $MAn_i$: Moving average of period $n$ at period $i$.
# - $n$: Period.
# - $C_i$: Closing price at period $i$.

# %% [markdown]
# $MA10_{i} = \frac{C_{i-9} + C_{i-8} + \cdots + C_{i-1} + C_i}{n}$

# %%
fb = pd.read_csv("ticker-fb.csv", index_col=0, parse_dates=True)

# %%
fb['Close'].rolling(2).sum().head()
# Out:
# Date
# 2018-01-02           NaN
# 2018-01-03    366.089996
# 2018-01-04    369.000000
# 2018-01-05    371.180008
# 2018-01-08    375.130005
# Name: Close, dtype: float64

# %%
fb['Close'].rolling(3).mean().head()
# Out:
# Date
# 2018-01-02           NaN
# 2018-01-03           NaN
# 2018-01-04    183.473333
# 2018-01-05    185.283335
# 2018-01-08    186.486669
# Name: Close, dtype: float64

# %%
fb['MA50'] = fb['Close'].rolling(50).mean()

# %%
fb.loc['2020-01-01':][['Close', 'MA50']].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fb['MA10'] = fb['Close'].rolling(10).mean()

# %%
fb.loc['2020-10-01':][['Close', 'MA10']].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Date'>

# %%
fb['Signal'] = fb['MA10'] < fb['Close']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-51786544fd25> in <module>
# ----> 1 fb['Signal'] = fb['MA10'] < fb['Close']
#
# NameError: name 'fb' is not defined

# %%
fb[['Close', 'MA10', 'Signal']].tail()
# Out:
#                  Close        MA10  Signal
# Date
# 2020-12-24  267.399994  272.522998    True
# 2020-12-28  277.000000  272.867999   False
# 2020-12-29  276.779999  273.126999   False
# 2020-12-30  271.869995  272.759000    True
# 2020-12-31  273.160004  272.507999   False
