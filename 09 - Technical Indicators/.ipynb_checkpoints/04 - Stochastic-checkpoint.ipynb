# %% [markdown]
# ### Stochastic oscillator
# - Lagging indicator
# - https://www.investopedia.com/terms/s/stochasticoscillator.asp
#
# **Calculations**
# - 14-high: Maximum of last 14 trading days
# - 14-low: Minimum of last 14 trading days
# - %K: (Last close - 14-low)*100 / (14-high - 14-low)
# - %D: Simple Moving Average of %K
#
# **Signal**
# - %K > %D

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
ticker = pd.read_csv("ticker-fb.csv", index_col=0, parse_dates=True)

# %%
high14 = ticker['High'].rolling(14).max()
low14 = ticker['Low'].rolling(14).min()
# %K: (Last close - 14-low)*100 / (14-high - 14-low)
ticker['%K'] = pct_k = (ticker['Close'] - low14)*100 / (high14 - low14)
ticker['%D'] = pct_d = pct_k.rolling(3).mean()
ticker['Signal'] = pct_k > pct_d

# %%
ticker.tail()
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-12-24  270.399994  266.200012  268.880005  267.399994   6702000
# 2020-12-28  277.299988  265.660004  268.739990  277.000000  23299700
# 2020-12-29  280.510010  276.279999  276.950012  276.779999  16383000
# 2020-12-30  278.079987  271.709991  277.950012  271.869995  11803800
# 2020-12-31  277.089996  269.809998  272.000000  273.160004  12892900
#
#              Adj Close         %K         %D  Signal
# Date
# 2020-12-24  267.399994  11.609349  12.168156   False
# 2020-12-28  277.000000  53.782587  26.658981    True
# 2020-12-29  276.779999  52.826060  39.405999    True
# 2020-12-30  271.869995  45.591864  50.733504   False
# 2020-12-31  273.160004  53.715341  50.711088    True

# %%
fig, ax = plt.subplots()
ticker.loc['2020-01-01':'2020-07-01'][['%K', '%D']].plot(ax=ax, alpha=0.5)
ax.axhline(80, c='r', alpha=0.3)
ax.axhline(20, c='r', alpha=0.3)
ticker.loc['2020-01-01':'2020-07-01']['Close'].plot(ax=ax, secondary_y=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:label='e2021a9a-317a-4e6d-8998-d714d3f4614b'>
