# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
data = pd.read_csv("result-full.csv", index_col=0, header=[0, 1])

# %%
data.head()
# Out:
#             DE Current   ROI   Revenue                           EPS  \
#      D/E ratio Current  Mean  10Y CAGR   5Y CAGR   1Y CAGR  10Y CAGR
# AAPL      True    True  True  0.197500  0.073149 -0.020411  0.249570
# MSFT      True    True  True  0.079727  0.077033  0.140295  0.120633
# AMZN      True    True  True  0.276040  0.258135  0.204541  0.274174
# GOOG      True    True  True  0.212071  0.196510  0.183001  0.170196
# FB        True    True  True  0.569994  0.414929  0.266109  0.516426
#
#                               BVPS                           FCF            \
#        5Y CAGR   1Y CAGR  10Y CAGR   5Y CAGR   1Y CAGR  10Y CAGR   5Y CAGR
# AAPL  0.130280 -0.003356  0.075461 -0.063686 -0.243615  0.206457  0.032706
# MSFT  0.139827  1.375587  0.115237  0.109523  0.174226  0.091656  0.072066
# AMZN       NaN  0.142502  0.277432  0.441417  0.444376  0.243557  0.676663
# GOOG  0.190352  0.124943       NaN  0.131984  0.113328  0.137953  0.207503
# ...

# %%
aapl = data.loc['AAPL']

# %%
aapl
# Out:
# DE       D/E ratio         True
# Current  Current           True
# ROI      Mean              True
# Revenue  10Y CAGR        0.1975
#          5Y CAGR      0.0731487
#          1Y CAGR     -0.0204108
# EPS      10Y CAGR       0.24957
#          5Y CAGR        0.13028
#          1Y CAGR     -0.0033557
# BVPS     10Y CAGR     0.0754613
#          5Y CAGR     -0.0636863
#          1Y CAGR      -0.243615
# FCF      10Y CAGR      0.206457
#          5Y CAGR      0.0327063
#          1Y CAGR     -0.0814866
# Name: AAPL, dtype: object

# %%
fig1, ax1 = plt.subplots()
aapl.loc['Revenue'].plot(ax=ax1, label='Revenue')
aapl.loc['EPS'].plot(ax=ax1, label='EPS')
aapl.loc['BVPS'].plot(ax=ax1, label='BVPS')
aapl.loc['FCF'].plot(ax=ax1, label='FCF')
ax1.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
aapl
# Out:
# DE       D/E ratio         True
# Current  Current           True
# ROI      Mean              True
# Revenue  10Y CAGR        0.1975
#          5Y CAGR      0.0731487
#          1Y CAGR     -0.0204108
# EPS      10Y CAGR       0.24957
#          5Y CAGR        0.13028
#          1Y CAGR     -0.0033557
# BVPS     10Y CAGR     0.0754613
#          5Y CAGR     -0.0636863
#          1Y CAGR      -0.243615
# FCF      10Y CAGR      0.206457
#          5Y CAGR      0.0327063
#          1Y CAGR     -0.0814866
# Name: AAPL, dtype: object

# %%
aapl_df = pd.DataFrame([aapl.loc['Revenue'], aapl.loc['EPS'], aapl.loc['BVPS'], aapl.loc['FCF']], index=['Revenue', 'EPS', 'BVPS', 'FCF'])

# %%
aapl_df
# Out:
#          10Y CAGR   5Y CAGR   1Y CAGR
# Revenue  0.197500  0.073149 -0.020411
# EPS      0.249570  0.130280 -0.003356
# BVPS     0.075461 -0.063686 -0.243615
# FCF      0.206457  0.032706 -0.081487

# %%
aapl_df2 = aapl.iloc[3:].unstack(1)

# %%
aapl_df2
# Out:
#           10Y CAGR    5Y CAGR    1Y CAGR
# Revenue     0.1975  0.0731487 -0.0204108
# EPS        0.24957    0.13028 -0.0033557
# BVPS     0.0754613 -0.0636863  -0.243615
# FCF       0.206457  0.0327063 -0.0814866

# %%
aapl_df2.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>
